# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('50_Startups.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 4].values

# %%
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        [144372.41, 118671.85, 383199.62, 'New York'],
#        [142107.34, 91391.77, 366168.42, 'Florida'],
#        [131876.9, 99814.71, 362861.36, 'New York'],
#        [134615.46, 147198.87, 127716.82, 'California'],
#        [130298.13, 145530.06, 323876.68, 'Florida'],
#        [120542.52, 148718.95, 311613.29, 'New York'],
#        [123334.88, 108679.17, 304981.62, 'California'],
#        [101913.08, 110594.11, 229160.95, 'Florida'],
#        [100671.96, 91790.61, 249744.55, 'California'],
#        [93863.75, 127320.38, 249839.44, 'Florida'],
#        [91992.39, 135495.07, 252664.93, 'California'],
#        [119943.24, 156547.42, 256512.92, 'Florida'],
#        [114523.61, 122616.84, 261776.23, 'New York'],
#        [78013.11, 121597.55, 264346.06, 'California'],
#        [94657.16, 145077.58, 282574.31, 'New York'],
#        [91749.16, 114175.79, 294919.57, 'Florida'],
#        [86419.7, 153514.11, 0.0, 'New York'],
#        [76253.86, 113867.3, 298664.47, 'California'],
#        [78389.47, 153773.43, 299737.29, 'New York'],
#        [73994.56, 122782.75, 303319.26, 'Florida'],
#        [67532.53, 105751.03, 304768.73, 'Florida'],
#        [77044.01, 99281.34, 140574.81, 'New York'],
#        [64664.71, 139553.16, 137962.62, 'California'],
#        [75328.87, 144135.98, 134050.07, 'Florida'],
#        [72107.6, 127864.55, 353183.81, 'New York'],
#        [66051.52, 182645.56, 118148.2, 'Florida'],
#        [65605.48, 153032.06, 107138.38, 'New York'],
#        [61994.48, 115641.28, 91131.24, 'Florida'],
#        [61136.38, 152701.92, 88218.23, 'New York'],
#        [63408.86, 129219.61, 46085.25, 'California'],
#        [55493.95, 103057.49, 214634.81, 'Florida'],
#        [46426.07, 157693.92, 210797.67, 'California'],
#        [46014.02, 85047.44, 205517.64, 'New York'],
#        [28663.76, 127056.21, 201126.82, 'Florida'],
#        [44069.95, 51283.14, 197029.42, 'California'],
#        [20229.59, 65947.93, 185265.1, 'New York'],
#        [38558.51, 82982.09, 174999.3, 'California'],
#        [28754.33, 118546.05, 172795.67, 'California'],
#        [27892.92, 84710.77, 164470.71, 'Florida'],
#        [23640.93, 96189.63, 148001.11, 'California'],
#        [15505.73, 127382.3, 35534.17, 'New York'],
#        [22177.74, 154806.14, 28334.72, 'California'],
#        [1000.23, 124153.04, 1903.93, 'New York'],
#        [1315.46, 115816.21, 297114.46, 'Florida'],
#        [0.0, 135426.92, 0.0, 'California'],
#        [542.05, 51743.15, 0.0, 'New York'],
#        [0.0, 116983.8, 45173.06, 'California']], dtype=object)

# %%
y
# Out:
# array([192261.83, 191792.06, 191050.39, 182901.99, 166187.94, 156991.12,
#        156122.51, 155752.6 , 152211.77, 149759.96, 146121.95, 144259.4 ,
#        141585.52, 134307.35, 132602.65, 129917.04, 126992.93, 125370.37,
#        124266.9 , 122776.86, 118474.03, 111313.02, 110352.25, 108733.99,
#        108552.04, 107404.34, 105733.54, 105008.31, 103282.38, 101004.64,
#         99937.59,  97483.56,  97427.84,  96778.92,  96712.8 ,  96479.51,
#         90708.19,  89949.14,  81229.06,  81005.76,  78239.91,  77798.83,
#         71498.49,  69758.98,  65200.33,  64926.08,  49490.75,  42559.73,
#         35673.41,  14681.4 ])

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# Country column
ct = ColumnTransformer([("State", OneHotEncoder(), [3])], remainder = 'passthrough')
X = ct.fit_transform(X)

# Male/Female
labelencoder_X = LabelEncoder()
X[:, 3] = labelencoder_X.fit_transform(X[:, 3])

# %%
ct
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('State', OneHotEncoder(), [3])])

# %%
X
# Out:
# array([[0.0, 0.0, 1.0, 48, 136897.8, 471784.1],
#        [1.0, 0.0, 0.0, 47, 151377.59, 443898.53],
#        [0.0, 1.0, 0.0, 46, 101145.55, 407934.54],
#        [0.0, 0.0, 1.0, 45, 118671.85, 383199.62],
#        [0.0, 1.0, 0.0, 44, 91391.77, 366168.42],
#        [0.0, 0.0, 1.0, 42, 99814.71, 362861.36],
#        [1.0, 0.0, 0.0, 43, 147198.87, 127716.82],
#        [0.0, 1.0, 0.0, 41, 145530.06, 323876.68],
#        [0.0, 0.0, 1.0, 39, 148718.95, 311613.29],
#        [1.0, 0.0, 0.0, 40, 108679.17, 304981.62],
#        [0.0, 1.0, 0.0, 36, 110594.11, 229160.95],
#        [1.0, 0.0, 0.0, 35, 91790.61, 249744.55],
#        [0.0, 1.0, 0.0, 33, 127320.38, 249839.44],
#        [1.0, 0.0, 0.0, 32, 135495.07, 252664.93],
#        [0.0, 1.0, 0.0, 38, 156547.42, 256512.92],
#        [0.0, 0.0, 1.0, 37, 122616.84, 261776.23],
#        [1.0, 0.0, 0.0, 28, 121597.55, 264346.06],
#        [0.0, 0.0, 1.0, 34, 145077.58, 282574.31],
#        [0.0, 1.0, 0.0, 31, 114175.79, 294919.57],
#        [0.0, 0.0, 1.0, 30, 153514.11, 0.0],
#        [1.0, 0.0, 0.0, 26, 113867.3, 298664.47],
#        [0.0, 0.0, 1.0, 29, 153773.43, 299737.29],
#        [0.0, 1.0, 0.0, 24, 122782.75, 303319.26],
#        [0.0, 1.0, 0.0, 22, 105751.03, 304768.73],
#        [0.0, 0.0, 1.0, 27, 99281.34, 140574.81],
#        [1.0, 0.0, 0.0, 19, 139553.16, 137962.62],
#        [0.0, 1.0, 0.0, 25, 144135.98, 134050.07],
#        [0.0, 0.0, 1.0, 23, 127864.55, 353183.81],
#        [0.0, 1.0, 0.0, 21, 182645.56, 118148.2],
#        [0.0, 0.0, 1.0, 20, 153032.06, 107138.38],
#        [0.0, 1.0, 0.0, 17, 115641.28, 91131.24],
#        [0.0, 0.0, 1.0, 16, 152701.92, 88218.23],
#        [1.0, 0.0, 0.0, 18, 129219.61, 46085.25],
#        [0.0, 1.0, 0.0, 15, 103057.49, 214634.81],
#        [1.0, 0.0, 0.0, 14, 157693.92, 210797.67],
#        [0.0, 0.0, 1.0, 13, 85047.44, 205517.64],
#        [0.0, 1.0, 0.0, 9, 127056.21, 201126.82],
#        [1.0, 0.0, 0.0, 12, 51283.14, 197029.42],
#        [0.0, 0.0, 1.0, 5, 65947.93, 185265.1],
#        [1.0, 0.0, 0.0, 11, 82982.09, 174999.3],
#        [1.0, 0.0, 0.0, 10, 118546.05, 172795.67],
#        [0.0, 1.0, 0.0, 8, 84710.77, 164470.71],
#        [1.0, 0.0, 0.0, 7, 96189.63, 148001.11],
#        [0.0, 0.0, 1.0, 4, 127382.3, 35534.17],
#        [1.0, 0.0, 0.0, 6, 154806.14, 28334.72],
#        [0.0, 0.0, 1.0, 2, 124153.04, 1903.93],
#        [0.0, 1.0, 0.0, 3, 115816.21, 297114.46],
#        [1.0, 0.0, 0.0, 0, 135426.92, 0.0],
#        [0.0, 0.0, 1.0, 1, 51743.15, 0.0],
#        [1.0, 0.0, 0.0, 0, 116983.8, 45173.06]], dtype=object)

# %%
# Avoiding the Dummy Variable Trap
X = X[:, 1:]

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
"""from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)"""
# Out:
# 'from sklearn.preprocessing import StandardScaler\nsc_X = StandardScaler()\nX_train = sc_X.fit_transform(X_train)\nX_test = sc_X.transform(X_test)\nsc_y = StandardScaler()\ny_train = sc_y.fit_transform(y_train)'

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %%
import statsmodels.api as sm
X_opt = np.array(X[:, [0, 1, 2, 3, 4, 5]], dtype=float)
#OrdinaryLeastSquares
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.927
# Method:                 Least Squares   F-statistic:                     125.8
# Date:                Wed, 29 Sep 2021   Prob (F-statistic):           6.61e-25
# Time:                        09:15:18   Log-Likelihood:                -532.46
# No. Observations:                  50   AIC:                             1077.
# Df Residuals:                      44   BIC:                             1088.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.033e+04   7948.436      6.333      0.000    3.43e+04    6.64e+04
# x1          -595.2931   3882.034     -0.153      0.879   -8419.019    7228.432
# x2          -678.8326   3754.684     -0.181      0.857   -8245.901    6888.236
# x3          2474.4082    168.178     14.713      0.000    2135.468    2813.348
# x4            -0.0289      0.060     -0.479      0.634      -0.151       0.093
# x5             0.0351      0.020      1.792      0.080      -0.004       0.075
# ==============================================================================
# Omnibus:                        6.879   Durbin-Watson:                   0.954
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                5.794
# Skew:                          -0.740   Prob(JB):                       0.0552
# Kurtosis:                       3.770   Cond. No.                     1.39e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.39e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_opt = np.array(X[:, [0, 1, 3, 4, 5]], dtype=float)
#OrdinaryLeastSquares
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     160.8
# Date:                Wed, 29 Sep 2021   Prob (F-statistic):           4.94e-26
# Time:                        09:17:48   Log-Likelihood:                -532.48
# No. Observations:                  50   AIC:                             1075.
# Df Residuals:                      45   BIC:                             1085.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.002e+04   7671.714      6.520      0.000    3.46e+04    6.55e+04
# x1          -249.2101   3340.776     -0.075      0.941   -6977.879    6479.458
# x2          2471.9013    165.794     14.909      0.000    2137.975    2805.828
# x3            -0.0287      0.060     -0.481      0.633      -0.149       0.092
# x4             0.0352      0.019      1.813      0.077      -0.004       0.074
# ==============================================================================
# Omnibus:                        6.857   Durbin-Watson:                   0.954
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                5.776
# Skew:                          -0.754   Prob(JB):                       0.0557
# Kurtosis:                       3.708   Cond. No.                     1.34e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_opt = np.array(X[:, [0, 3, 4, 5]], dtype=float)
#OrdinaryLeastSquares
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     219.1
# Date:                Wed, 29 Sep 2021   Prob (F-statistic):           3.06e-27
# Time:                        09:18:14   Log-Likelihood:                -532.48
# No. Observations:                  50   AIC:                             1073.
# Df Residuals:                      46   BIC:                             1081.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const           5e+04   7584.184      6.593      0.000    3.47e+04    6.53e+04
# x1          2472.7580    163.598     15.115      0.000    2143.452    2802.064
# x2            -0.0289      0.059     -0.490      0.627      -0.148       0.090
# x3             0.0349      0.019      1.852      0.071      -0.003       0.073
# ==============================================================================
# Omnibus:                        6.748   Durbin-Watson:                   0.952
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):                5.661
# Skew:                          -0.748   Prob(JB):                       0.0590
# Kurtosis:                       3.690   Cond. No.                     1.34e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_opt = np.array(X[:, [0,3,5]], dtype=float)
#OrdinaryLeastSquares
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.934
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     333.9
# Date:                Wed, 29 Sep 2021   Prob (F-statistic):           1.66e-28
# Time:                        09:18:47   Log-Likelihood:                -532.61
# No. Observations:                  50   AIC:                             1071.
# Df Residuals:                      47   BIC:                             1077.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.662e+04   3108.554     14.997      0.000    4.04e+04    5.29e+04
# x1          2441.1308    149.083     16.374      0.000    2141.214    2741.047
# x2             0.0378      0.018      2.132      0.038       0.002       0.073
# ==============================================================================
# Omnibus:                        7.047   Durbin-Watson:                   0.943
# Prob(Omnibus):                  0.029   Jarque-Bera (JB):                5.980
# Skew:                          -0.763   Prob(JB):                       0.0503
# Kurtosis:                       3.734   Cond. No.                     5.07e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.07e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_opt = np.array(X[:, [0, 3]], dtype=float)
#OrdinaryLeastSquares
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.928
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     617.6
# Date:                Wed, 29 Sep 2021   Prob (F-statistic):           4.64e-29
# Time:                        09:19:05   Log-Likelihood:                -534.92
# No. Observations:                  50   AIC:                             1074.
# Df Residuals:                      48   BIC:                             1078.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.922e+04   2962.264     16.617      0.000    4.33e+04    5.52e+04
# x1          2669.5844    107.419     24.852      0.000    2453.605    2885.564
# ==============================================================================
# Omnibus:                        4.564   Durbin-Watson:                   0.791
# Prob(Omnibus):                  0.102   Jarque-Bera (JB):                3.434
# Skew:                          -0.533   Prob(JB):                        0.180
# Kurtosis:                       3.716   Cond. No.                         52.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
